# %% [markdown]
# # Dataset taken from
# <a>https://platform.stratascratch.com/data-projects/delivery-duration-prediction</a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
import sklearn.metrics as metrics

import pandas as pd
import numpy as np
import statistics
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta
from math import sqrt

from sklearn.model_selection  import train_test_split
from sklearn.model_selection import cross_val_score, KFold, GridSearchCV
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.cluster import KMeans
from sklearn import tree
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix, classification_report

# %matplotlib inline
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns 
import scipy.stats as scs
import scipy.stats as stats

import statsmodels.api as sm
from datetime import date, datetime, time

# %%
#read dataset
df = pd.read_csv("historical_data.csv")
df.head()
# Out:
#    market_id           created_at actual_delivery_time  store_id  \
# 0        1.0  2015-02-06 22:24:17  2015-02-06 23:27:16      1845
# 1        2.0  2015-02-10 21:49:25  2015-02-10 22:56:29      5477
# 2        3.0  2015-01-22 20:39:28  2015-01-22 21:09:09      5477
# 3        3.0  2015-02-03 21:21:45  2015-02-03 22:13:00      5477
# 4        3.0  2015-02-15 02:40:36  2015-02-15 03:20:26      5477
#
#   store_primary_category  order_protocol  total_items  subtotal  \
# 0               american             1.0            4      3441
# 1                mexican             2.0            1      1900
# 2                    NaN             1.0            1      1900
# 3                    NaN             1.0            6      6900
# 4                    NaN             1.0            3      3900
#
#    num_distinct_items  min_item_price  max_item_price  total_onshift_dashers  \
# 0                   4             557            1239                   33.0
# 1                   1            1400            1400                    1.0
# 2                   1            1900            1900                    1.0
# 3                   5             600            1800                    1.0
# 4                   3            1100            1600                    6.0
#
#    total_busy_dashers  total_outstanding_orders  \
# 0                14.0                      21.0
# 1                 2.0                       2.0
# 2                 0.0                       0.0
# 3                 1.0                       2.0
# 4                 6.0                       9.0
#
#    estimated_order_place_duration  \
# 0                             446
# 1                             446
# 2                             446
# 3                             446
# 4                             446
#
#    estimated_store_to_consumer_driving_duration
# 0                                         861.0
# 1                                         690.0
# 2                                         690.0
# 3                                         289.0
# 4                                         650.0

# %%
df.shape
# Out:
# (197428, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197428 entries, 0 to 197427
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   market_id                                     196441 non-null  float64
#  1   created_at                                    197428 non-null  object
#  2   actual_delivery_time                          197421 non-null  object
#  3   store_id                                      197428 non-null  int64
#  4   store_primary_category                        192668 non-null  object
#  5   order_protocol                                196433 non-null  float64
#  6   total_items                                   197428 non-null  int64
#  7   subtotal                                      197428 non-null  int64
#  8   num_distinct_items                            197428 non-null  int64
#  9   min_item_price                                197428 non-null  int64
#  10  max_item_price                                197428 non-null  int64
#  11  total_onshift_dashers                         181166 non-null  float64
#  12  total_busy_dashers                            181166 non-null  float64
#  13  total_outstanding_orders                      181166 non-null  float64
#  14  estimated_order_place_duration                197428 non-null  int64
#  15  estimated_store_to_consumer_driving_duration  196902 non-null  float64
# dtypes: float64(6), int64(7), object(3)
# memory usage: 24.1+ MB

# %%
#checking for null vals
df.isnull().sum()
# Out:
# market_id                                         987
# created_at                                          0
# actual_delivery_time                                7
# store_id                                            0
# store_primary_category                           4760
# order_protocol                                    995
# total_items                                         0
# subtotal                                            0
# num_distinct_items                                  0
# min_item_price                                      0
# max_item_price                                      0
# total_onshift_dashers                           16262
# total_busy_dashers                              16262
# total_outstanding_orders                        16262
# estimated_order_place_duration                      0
# estimated_store_to_consumer_driving_duration      526
# dtype: int64

# %%
# converting object data types to date datatype
df['created_at'] = pd.to_datetime(df['created_at'])
df['actual_delivery_time'] = pd.to_datetime(df['actual_delivery_time'])

# %%
#creating feature delivery duration that would be helpful in delivery duration prediction
#New column for delievry duration for ML prediction
df['delivery_duration'] = df['actual_delivery_time'] - df['created_at']
df['delivery_duration_secs'] = df['delivery_duration'].dt.total_seconds()

# %%
#drop the null values 
df = df[df['actual_delivery_time'].notna()]
df = df[df['delivery_duration'].notna()]
df = df[df['delivery_duration_secs'].notna()]
df = df[df['market_id'].notna()]
#df.head()

# %%
#Extracting Hour/Day/Month info
#created_at to week, hour, month
df['create_week'] = df['created_at'].dt.dayofweek
df['create_hour'] = df['created_at'].dt.hour
df['create_month'] = df['created_at'].dt.month

# %%
# fill up nan with same marketid mean and same created hour mean by group by
df["total_onshift_dashers"] = df.groupby(["market_id",'create_hour'])['total_onshift_dashers'].transform(lambda x: x.fillna(x.mean()))
df["total_busy_dashers"] = df.groupby(["market_id",'create_hour'])['total_busy_dashers'].transform(lambda x: x.fillna(x.mean()))
df["total_outstanding_orders"] =df.groupby(["market_id",'create_hour'])['total_outstanding_orders'].transform(lambda x: x.fillna(x.mean()))
#df.head()

# %%
# We have negative values in some columns total_onshift_dashers, total_busy_dashers, total_outstanding_orders, min_item_price
df.describe()
# Out:
#            market_id       store_id  order_protocol    total_items  \
# count  196434.000000  196434.000000   195926.000000  196434.000000
# mean        2.978700    3530.472087        2.882185       3.196249
# std         1.524879    2053.184065        1.503725       2.667770
# min         1.000000       1.000000        1.000000       1.000000
# 25%         2.000000    1686.000000        1.000000       2.000000
# 50%         3.000000    3591.500000        3.000000       3.000000
# 75%         4.000000    5299.000000        4.000000       4.000000
# max         6.000000    6987.000000        7.000000     411.000000
#
#             subtotal  num_distinct_items  min_item_price  max_item_price  \
# count  196434.000000       196434.000000   196434.000000   196434.000000
# mean     2682.366729            2.670790      686.315429     1159.704705
# std      1823.156066            1.630409      522.345360      558.604932
# min         0.000000            1.000000      -86.000000        0.000000
# 25%      1400.000000            1.000000      299.000000      800.000000
# 50%      2200.000000            2.000000      595.000000     1095.000000
# 75%      3395.000000            3.000000      949.000000     1395.000000
# max     27100.000000           20.000000    14700.000000    14700.000000
#
#        total_onshift_dashers  total_busy_dashers  total_outstanding_orders  \
# count          196432.000000       196432.000000             196432.000000
# mean               44.699045           41.654869                 57.978908
# std                33.638941           31.290037                 51.372007
# min                -4.000000           -5.000000                 -6.000000
# 25%                18.000000           16.000000                 18.000000
# 50%                37.000000           35.000000                 42.000000
# 75%                65.362832           61.000000                 86.000000
# max               171.000000          154.000000                285.000000
#
#        estimated_order_place_duration  \
# count                   196434.000000
# mean                       308.575761
# std                         90.149404
# min                          0.000000
# 25%                        251.000000
# 50%                        251.000000
# 75%                        446.000000
# max                       2715.000000
#
#        estimated_store_to_consumer_driving_duration  \
# count                                 195909.000000
# mean                                     545.299705
# std                                      219.345707
# min                                        0.000000
# 25%                                      382.000000
# 50%                                      544.000000
# 75%                                      702.000000
# max                                     2088.000000
#
#                delivery_duration  delivery_duration_secs    create_week  \
# count                     196434            1.964340e+05  196434.000000
# mean   0 days 00:48:28.409155237            2.908409e+03       3.219682
# std    0 days 05:21:17.693369047            1.927769e+04       2.045671
# min              0 days 00:01:41            1.010000e+02       0.000000
# 25%              0 days 00:35:04            2.104000e+03       1.000000
# 50%              0 days 00:44:20            2.660000e+03       3.000000
# 75%              0 days 00:56:21            3.381000e+03       5.000000
# max             98 days 13:47:39            8.516859e+06       6.000000
#
#          create_hour   create_month
# count  196434.000000  196434.000000
# mean        8.468875       1.653095
# std         8.659225       0.476371
# min         0.000000       1.000000
# 25%         2.000000       1.000000
# 50%         3.000000       2.000000
# 75%        19.000000       2.000000
# max        23.000000      10.000000

# %%
#Make all the negative values to positive 
#Transformation
df.total_onshift_dashers = df.total_onshift_dashers.abs()
df.total_busy_dashers = df.total_busy_dashers.abs()
df.total_outstanding_orders = df.total_outstanding_orders.abs()
df.min_item_price = df.min_item_price.abs()
df.describe()
# Out:
#            market_id       store_id  order_protocol    total_items  \
# count  196434.000000  196434.000000   195926.000000  196434.000000
# mean        2.978700    3530.472087        2.882185       3.196249
# std         1.524879    2053.184065        1.503725       2.667770
# min         1.000000       1.000000        1.000000       1.000000
# 25%         2.000000    1686.000000        1.000000       2.000000
# 50%         3.000000    3591.500000        3.000000       3.000000
# 75%         4.000000    5299.000000        4.000000       4.000000
# max         6.000000    6987.000000        7.000000     411.000000
#
#             subtotal  num_distinct_items  min_item_price  max_item_price  \
# count  196434.000000       196434.000000   196434.000000   196434.000000
# mean     2682.366729            2.670790      686.319318     1159.704705
# std      1823.156066            1.630409      522.340249      558.604932
# min         0.000000            1.000000        0.000000        0.000000
# 25%      1400.000000            1.000000      299.000000      800.000000
# 50%      2200.000000            2.000000      595.000000     1095.000000
# 75%      3395.000000            3.000000      949.000000     1395.000000
# max     27100.000000           20.000000    14700.000000    14700.000000
#
#        total_onshift_dashers  total_busy_dashers  total_outstanding_orders  \
# count          196432.000000       196432.000000             196432.000000
# mean               44.699442           41.655256                 57.980171
# std                33.638414           31.289522                 51.370582
# min                 0.000000            0.000000                  0.000000
# 25%                18.000000           16.000000                 18.000000
# 50%                37.000000           35.000000                 42.000000
# 75%                65.362832           61.000000                 86.000000
# max               171.000000          154.000000                285.000000
#
#        estimated_order_place_duration  \
# count                   196434.000000
# mean                       308.575761
# std                         90.149404
# min                          0.000000
# 25%                        251.000000
# 50%                        251.000000
# 75%                        446.000000
# max                       2715.000000
#
#        estimated_store_to_consumer_driving_duration  \
# count                                 195909.000000
# mean                                     545.299705
# std                                      219.345707
# min                                        0.000000
# 25%                                      382.000000
# 50%                                      544.000000
# 75%                                      702.000000
# max                                     2088.000000
#
#                delivery_duration  delivery_duration_secs    create_week  \
# count                     196434            1.964340e+05  196434.000000
# mean   0 days 00:48:28.409155237            2.908409e+03       3.219682
# std    0 days 05:21:17.693369047            1.927769e+04       2.045671
# min              0 days 00:01:41            1.010000e+02       0.000000
# 25%              0 days 00:35:04            2.104000e+03       1.000000
# 50%              0 days 00:44:20            2.660000e+03       3.000000
# 75%              0 days 00:56:21            3.381000e+03       5.000000
# max             98 days 13:47:39            8.516859e+06       6.000000
#
#          create_hour   create_month
# count  196434.000000  196434.000000
# mean        8.468875       1.653095
# std         8.659225       0.476371
# min         0.000000       1.000000
# 25%         2.000000       1.000000
# 50%         3.000000       2.000000
# 75%        19.000000       2.000000
# max        23.000000      10.000000

# %%
#removing outliers
num_columns = ['total_items',  'subtotal', 'num_distinct_items', 'min_item_price','max_item_price','total_onshift_dashers'
                   ,'total_busy_dashers','total_outstanding_orders','delivery_duration_secs']
for i in num_columns:
    df = df[(df[i] <= df[i].quantile(0.999))]
    
df.describe()
# Out:
#            market_id       store_id  order_protocol    total_items  \
# count  194746.000000  194746.000000   194243.000000  194746.000000
# mean        2.979984    3531.057352        2.881792       3.148101
# std         1.526081    2053.630161        1.504480       2.273931
# min         1.000000       1.000000        1.000000       1.000000
# 25%         2.000000    1686.000000        1.000000       2.000000
# 50%         3.000000    3592.000000        3.000000       3.000000
# 75%         4.000000    5299.000000        4.000000       4.000000
# max         6.000000    6987.000000        7.000000      25.000000
#
#             subtotal  num_distinct_items  min_item_price  max_item_price  \
# count  194746.000000       194746.000000   194746.000000   194746.000000
# mean     2654.279046            2.652732      682.601635     1150.900116
# std      1758.759268            1.580761      499.567132      522.923351
# min         0.000000            1.000000        0.000000        0.000000
# 25%      1400.000000            1.000000      299.000000      799.000000
# 50%      2200.000000            2.000000      595.000000     1095.000000
# 75%      3380.000000            3.000000      949.000000     1395.000000
# max     13150.000000           11.000000     4248.000000     4300.000000
#
#        total_onshift_dashers  total_busy_dashers  total_outstanding_orders  \
# count          194746.000000       194746.000000             194746.000000
# mean               44.456941           41.414530                 57.583568
# std                33.330536           30.964538                 50.758988
# min                 0.000000            0.000000                  0.000000
# 25%                18.000000           16.000000                 18.000000
# 50%                37.000000           35.000000                 42.000000
# 75%                65.362832           61.000000                 86.000000
# max               152.000000          141.000000                256.000000
#
#        estimated_order_place_duration  \
# count                   194746.000000
# mean                       308.649913
# std                         90.180083
# min                          0.000000
# 25%                        251.000000
# 50%                        251.000000
# 75%                        446.000000
# max                       2715.000000
#
#        estimated_store_to_consumer_driving_duration  \
# count                                 194223.000000
# mean                                     545.129063
# std                                      219.367897
# min                                        0.000000
# 25%                                      382.000000
# 50%                                      543.000000
# 75%                                      702.000000
# max                                     2088.000000
#
#                delivery_duration  delivery_duration_secs    create_week  \
# count                     194746           194746.000000  194746.000000
# mean   0 days 00:47:24.914185657             2844.914186       3.215054
# std    0 days 00:17:52.908888377             1072.908888       2.045389
# min              0 days 00:01:41              101.000000       0.000000
# 25%              0 days 00:35:00             2100.000000       1.000000
# 50%              0 days 00:44:14             2654.000000       3.000000
# 75%              0 days 00:56:12             3372.000000       5.000000
# max              0 days 02:44:58             9898.000000       6.000000
#
#          create_hour   create_month
# count  194746.000000  194746.000000
# mean        8.486331       1.652968
# std         8.665172       0.476027
# min         0.000000       1.000000
# 25%         2.000000       1.000000
# 50%         3.000000       2.000000
# 75%        19.000000       2.000000
# max        23.000000       2.000000

# %%
#converting categorical values to numerical
#categorical encoding
df.store_primary_category = LabelEncoder().fit_transform(df.store_primary_category)
#restoring null values
#df.store_primary_category = df.store_primary_category.replace([74], float("nan") )
#df.head(15)

# %%
#we are dropping this column because it has negative values and impacting our result
df.drop(['store_primary_category'], axis=1, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.columns[16:]
# Out:
# Index(['delivery_duration_secs', 'create_week', 'create_hour', 'create_month'], dtype='object')

# %%
#normalizing and standardization in subsets to avoid datetime columns
normalized_df1 = MinMaxScaler().fit_transform(df[df.columns[6:15]])
normalized_df1 = StandardScaler().fit_transform(normalized_df1)
normalized_df1 = pd.DataFrame(normalized_df1,columns= df.columns[6:15])

normalized_df1.head()
# Out:
#    subtotal  num_distinct_items  min_item_price  max_item_price  \
# 0  0.447317            0.852293       -0.251422        0.168476
# 1 -0.428871           -1.045532        1.436044        0.476361
# 2 -0.428871           -1.045532        2.436913        1.432527
# 3  2.414049            1.484901       -0.165347        1.241294
# 4  0.708297            0.219685        0.835522        0.858828
#
#    total_onshift_dashers  total_busy_dashers  total_outstanding_orders  \
# 0              -0.343738           -0.885355                 -0.720733
# 1              -1.303821           -1.272896                 -1.095052
# 2              -1.303821           -1.337486                 -1.134454
# 3              -1.303821           -1.305191                 -1.095052
# 4              -1.153808           -1.143715                 -0.957145
#
#    estimated_order_place_duration  \
# 0                        1.523068
# 1                        1.523068
# 2                        1.523068
# 3                        1.523068
# 4                        1.523068
#
#    estimated_store_to_consumer_driving_duration
# 0                                      1.439918
# 1                                      0.660403
# 2                                      0.660403
# 3                                     -1.167581
# 4                                      0.478061

# %%
normalized_df2 = MinMaxScaler().fit_transform(df[df.columns[16:]])
normalized_df2 = StandardScaler().fit_transform(normalized_df2)
normalized_df2 = pd.DataFrame(normalized_df2,columns= df.columns[16:])
normalized_df2.head()
# Out:
#    delivery_duration_secs  create_week  create_hour  create_month
# 0                0.870613     0.383764     1.559542      0.729018
# 1                1.098965    -1.082953     1.444138      0.729018
# 2               -0.991619    -0.105141     1.328733     -1.371708
# 3                0.214451    -1.082953     1.444138      0.729018
# 4               -0.424002     1.361576    -0.748554      0.729018

# %%
#joining the normalized subsets back with the dataset
df1 = df[df.columns[:6]]
df1.reset_index(drop=True, inplace=True)
df2 = df[df.columns[15]]
df2.reset_index(drop=True, inplace=True)
normalized_df1.reset_index(drop=True, inplace=True)
normalized_df2.reset_index(drop=True, inplace=True)
df = pd.concat([df1, normalized_df1, df2, normalized_df2], axis=1)
df.head()
# Out:
#    market_id          created_at actual_delivery_time  store_id  \
# 0        1.0 2015-02-06 22:24:17  2015-02-06 23:27:16      1845
# 1        2.0 2015-02-10 21:49:25  2015-02-10 22:56:29      5477
# 2        3.0 2015-01-22 20:39:28  2015-01-22 21:09:09      5477
# 3        3.0 2015-02-03 21:21:45  2015-02-03 22:13:00      5477
# 4        3.0 2015-02-15 02:40:36  2015-02-15 03:20:26      5477
#
#    order_protocol  total_items  subtotal  num_distinct_items  min_item_price  \
# 0             1.0            4  0.447317            0.852293       -0.251422
# 1             2.0            1 -0.428871           -1.045532        1.436044
# 2             1.0            1 -0.428871           -1.045532        2.436913
# 3             1.0            6  2.414049            1.484901       -0.165347
# 4             1.0            3  0.708297            0.219685        0.835522
#
#    max_item_price  total_onshift_dashers  total_busy_dashers  \
# 0        0.168476              -0.343738           -0.885355
# 1        0.476361              -1.303821           -1.272896
# 2        1.432527              -1.303821           -1.337486
# 3        1.241294              -1.303821           -1.305191
# 4        0.858828              -1.153808           -1.143715
#
#    total_outstanding_orders  estimated_order_place_duration  \
# 0                 -0.720733                        1.523068
# 1                 -1.095052                        1.523068
# 2                 -1.134454                        1.523068
# 3                 -1.095052                        1.523068
# 4                 -0.957145                        1.523068
#
#    estimated_store_to_consumer_driving_duration delivery_duration  \
# 0                                      1.439918   0 days 01:02:59
# 1                                      0.660403   0 days 01:07:04
# 2                                      0.660403   0 days 00:29:41
# 3                                     -1.167581   0 days 00:51:15
# 4                                      0.478061   0 days 00:39:50
#
#    delivery_duration_secs  create_week  create_hour  create_month
# 0                0.870613     0.383764     1.559542      0.729018
# 1                1.098965    -1.082953     1.444138      0.729018
# 2               -0.991619    -0.105141     1.328733     -1.371708
# 3                0.214451    -1.082953     1.444138      0.729018
# 4               -0.424002     1.361576    -0.748554      0.729018

# %%
#drop column because these were redundant
updated_df = df.drop(['created_at', 'order_protocol', 'delivery_duration'],axis=1)
updated_df.reset_index(inplace=True, drop=True)

# %%
updated_df.isna().sum()
# Out:
# market_id                                         0
# actual_delivery_time                              0
# store_id                                          0
# total_items                                       0
# subtotal                                          0
# num_distinct_items                                0
# min_item_price                                    0
# max_item_price                                    0
# total_onshift_dashers                             0
# total_busy_dashers                                0
# total_outstanding_orders                          0
# estimated_order_place_duration                    0
# estimated_store_to_consumer_driving_duration    523
# delivery_duration_secs                            0
# create_week                                       0
# create_hour                                       0
# create_month                                      0
# dtype: int64

# %%
updated_df = updated_df[updated_df['estimated_store_to_consumer_driving_duration'].notna()]

# %%
updated_df.isna().sum()
# Out:
# market_id                                       0
# actual_delivery_time                            0
# store_id                                        0
# total_items                                     0
# subtotal                                        0
# num_distinct_items                              0
# min_item_price                                  0
# max_item_price                                  0
# total_onshift_dashers                           0
# total_busy_dashers                              0
# total_outstanding_orders                        0
# estimated_order_place_duration                  0
# estimated_store_to_consumer_driving_duration    0
# delivery_duration_secs                          0
# create_week                                     0
# create_hour                                     0
# create_month                                    0
# dtype: int64

# %%
updated_df.shape
# Out:
# (194223, 17)

# %%
# #PCA
# pca = PCA(n_components = 10)

# %%
# X_train_pca = pca.fit_transform(updated_df)

# %%
#validation- checking for duplicates
duplicateRows = updated_df[updated_df.duplicated()]
duplicateRows
# Out:
# Empty DataFrame
# Columns: [market_id, actual_delivery_time, store_id, total_items, subtotal, num_distinct_items, min_item_price, max_item_price, total_onshift_dashers, total_busy_dashers, total_outstanding_orders, estimated_order_place_duration, estimated_store_to_consumer_driving_duration, delivery_duration_secs, create_week, create_hour, create_month]
# Index: []

# %% [markdown]
#  # Univariate Analysis

# %%
df=pd.read_csv('historical_data.csv')

# %%
df.describe()
# Out:
#            market_id       store_id  order_protocol    total_items  \
# count  196441.000000  197428.000000   196433.000000  197428.000000
# mean        2.978706    3530.510272        2.882352       3.196391
# std         1.524867    2053.496711        1.503771       2.666546
# min         1.000000       1.000000        1.000000       1.000000
# 25%         2.000000    1686.000000        1.000000       2.000000
# 50%         3.000000    3592.000000        3.000000       3.000000
# 75%         4.000000    5299.000000        4.000000       4.000000
# max         6.000000    6987.000000        7.000000     411.000000
#
#             subtotal  num_distinct_items  min_item_price  max_item_price  \
# count  197428.000000       197428.000000   197428.000000   197428.000000
# mean     2682.331402            2.670791      686.218470     1159.588630
# std      1823.093688            1.630255      522.038648      558.411377
# min         0.000000            1.000000      -86.000000        0.000000
# 25%      1400.000000            1.000000      299.000000      800.000000
# 50%      2200.000000            2.000000      595.000000     1095.000000
# 75%      3395.000000            3.000000      949.000000     1395.000000
# max     27100.000000           20.000000    14700.000000    14700.000000
#
#        total_onshift_dashers  total_busy_dashers  total_outstanding_orders  \
# count          181166.000000       181166.000000             181166.000000
# mean               44.808093           41.739747                 58.050065
# std                34.526783           32.145733                 52.661830
# min                -4.000000           -5.000000                 -6.000000
# 25%                17.000000           15.000000                 17.000000
# 50%                37.000000           34.000000                 41.000000
# 75%                65.000000           62.000000                 85.000000
# max               171.000000          154.000000                285.000000
#
#        estimated_order_place_duration  \
# count                   197428.000000
# mean                       308.560179
# std                         90.139653
# min                          0.000000
# 25%                        251.000000
# 50%                        251.000000
# 75%                        446.000000
# max                       2715.000000
#
#        estimated_store_to_consumer_driving_duration
# count                                 196902.000000
# mean                                     545.358935
# std                                      219.352902
# min                                        0.000000
# 25%                                      382.000000
# 50%                                      544.000000
# 75%                                      702.000000
# max                                     2088.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197428 entries, 0 to 197427
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   market_id                                     196441 non-null  float64
#  1   created_at                                    197428 non-null  object
#  2   actual_delivery_time                          197421 non-null  object
#  3   store_id                                      197428 non-null  int64
#  4   store_primary_category                        192668 non-null  object
#  5   order_protocol                                196433 non-null  float64
#  6   total_items                                   197428 non-null  int64
#  7   subtotal                                      197428 non-null  int64
#  8   num_distinct_items                            197428 non-null  int64
#  9   min_item_price                                197428 non-null  int64
#  10  max_item_price                                197428 non-null  int64
#  11  total_onshift_dashers                         181166 non-null  float64
#  12  total_busy_dashers                            181166 non-null  float64
#  13  total_outstanding_orders                      181166 non-null  float64
#  14  estimated_order_place_duration                197428 non-null  int64
#  15  estimated_store_to_consumer_driving_duration  196902 non-null  float64
# dtypes: float64(6), int64(7), object(3)
# memory usage: 24.1+ MB

# %%
df.isna().sum()
# Out:
# market_id                                         987
# created_at                                          0
# actual_delivery_time                                7
# store_id                                            0
# store_primary_category                           4760
# order_protocol                                    995
# total_items                                         0
# subtotal                                            0
# num_distinct_items                                  0
# min_item_price                                      0
# max_item_price                                      0
# total_onshift_dashers                           16262
# total_busy_dashers                              16262
# total_outstanding_orders                        16262
# estimated_order_place_duration                      0
# estimated_store_to_consumer_driving_duration      526
# dtype: int64

# %%
# Analysing distribution of all columns
df.total_onshift_dashers.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.total_outstanding_orders.hist()
# Out:
# <AxesSubplot:>

# %%
df.total_busy_dashers.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.market_id.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.total_items.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.subtotal.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.num_distinct_items.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.min_item_price.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.order_protocol.hist()
# Out:
# <AxesSubplot:>

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Creating Boxplot of Numerical Columns to see any outliers

num_columns = ['total_items',  'subtotal', 'num_distinct_items', 'min_item_price','max_item_price','total_onshift_dashers'
                   ,'total_busy_dashers','total_outstanding_orders']
for i in num_columns:
    boxplt = df.boxplot(column=[i])
    plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
#Checking co-relation of all the variables to find the relationshio

df2=updated_df.corr()
print(df2)
# Out:
#                                               market_id  store_id  \
# market_id                                      1.000000  0.017393
# store_id                                       0.017393  1.000000
# total_items                                   -0.008050 -0.009569
# subtotal                                      -0.017392 -0.013073
# num_distinct_items                             0.000929 -0.013033
# min_item_price                                 0.001045 -0.008014
# max_item_price                                -0.002757 -0.019012
# total_onshift_dashers                          0.065754 -0.021962
# total_busy_dashers                             0.058037 -0.022198
# total_outstanding_orders                       0.064395 -0.019576
# estimated_order_place_duration                -0.053183  0.017037
# estimated_store_to_consumer_driving_duration   0.006854  0.001913
# delivery_duration_secs                        -0.049624 -0.009647
# create_week                                   -0.002365 -0.000465
# create_hour                                   -0.014624  0.010008
# create_month                                   0.042108  0.003774
#
#                                               total_items  subtotal  \
# market_id                                       -0.008050 -0.017392
# store_id                                        -0.009569 -0.013073
# total_items                                      1.000000  0.623052
# subtotal                                         0.623052  1.000000
# num_distinct_items                               0.842965  0.679730
# min_item_price                                  -0.452736  0.026496
# max_item_price                                  -0.056881  0.513033
# total_onshift_dashers                            0.039693  0.135509
# total_busy_dashers                               0.035413  0.129659
# total_outstanding_orders                         0.041831  0.134613
# estimated_order_place_duration                  -0.018311  0.042393
# estimated_store_to_consumer_driving_duration     0.007910  0.034453
# delivery_duration_secs                           0.129359  0.215657
# create_week                                      0.028826  0.035009
# create_hour                                     -0.080102 -0.192589
# create_month                                    -0.005475 -0.005756
#
#                                               num_distinct_items  \
# market_id                                               0.000929
# store_id                                               -0.013033
# total_items                                             0.842965
# subtotal                                                0.679730
# num_distinct_items                                      1.000000
# min_item_price                                         -0.466307
# max_item_price                                          0.050520
# total_onshift_dashers                                   0.067757
# total_busy_dashers                                      0.062071
# total_outstanding_orders                                0.069284
# estimated_order_place_duration                          0.007291
# estimated_store_to_consumer_driving_duration            0.022860
# delivery_duration_secs                                  0.154516
# create_week                                             0.032868
# create_hour                                            -0.119512
# create_month                                           -0.002032
#
#                                               min_item_price  max_item_price  \
# market_id                                           0.001045       -0.002757
# store_id                                           -0.008014       -0.019012
# total_items                                        -0.452736       -0.056881
# subtotal                                            0.026496        0.513033
# num_distinct_items                                 -0.466307        0.050520
# min_item_price                                      1.000000        0.528677
# max_item_price                                      0.528677        1.000000
# total_onshift_dashers                               0.045494        0.143101
# total_busy_dashers                                  0.046686        0.140248
# total_outstanding_orders                            0.044006        0.140401
# estimated_order_place_duration                      0.052849        0.085878
# estimated_store_to_consumer_driving_duration        0.001838        0.026043
# delivery_duration_secs                              0.014959        0.139452
# create_week                                        -0.002013        0.029479
# create_hour                                        -0.053613       -0.197267
# create_month                                        0.003308        0.005389
#
#                                               total_onshift_dashers  \
# market_id                                                  0.065754
# store_id                                                  -0.021962
# total_items                                                0.039693
# subtotal                                                   0.135509
# num_distinct_items                                         0.067757
# min_item_price                                             0.045494
# max_item_price                                             0.143101
# total_onshift_dashers                                      1.000000
# total_busy_dashers                                         0.945838
# total_outstanding_orders                                   0.938196
# estimated_order_place_duration                            -0.178175
# estimated_store_to_consumer_driving_duration               0.041857
# delivery_duration_secs                                     0.077946
# create_week                                                0.086620
# create_hour                                               -0.382202
# create_month                                               0.023269
#
#                                               total_busy_dashers  \
# market_id                                               0.058037
# store_id                                               -0.022198
# total_items                                             0.035413
# subtotal                                                0.129659
# num_distinct_items                                      0.062071
# min_item_price                                          0.046686
# max_item_price                                          0.140248
# total_onshift_dashers                                   0.945838
# total_busy_dashers                                      1.000000
# total_outstanding_orders                                0.935364
# estimated_order_place_duration                         -0.184425
# estimated_store_to_consumer_driving_duration            0.040316
# delivery_duration_secs                                  0.096235
# create_week                                             0.069732
# create_hour                                            -0.358519
# create_month                                           -0.043374
#
#                                               total_outstanding_orders  \
# market_id                                                     0.064395
# store_id                                                     -0.019576
# total_items                                                   0.041831
# subtotal                                                      0.134613
# num_distinct_items                                            0.069284
# min_item_price                                                0.044006
# max_item_price                                                0.140401
# total_onshift_dashers                                         0.938196
# total_busy_dashers                                            0.935364
# total_outstanding_orders                                      1.000000
# estimated_order_place_duration                               -0.166006
# estimated_store_to_consumer_driving_duration                  0.035992
# delivery_duration_secs                                        0.186469
# create_week                                                   0.072138
# create_hour                                                  -0.370555
# create_month                                                  0.042183
#
#                                               estimated_order_place_duration  \
# market_id                                                          -0.053183
# store_id                                                            0.017037
# total_items                                                        -0.018311
# subtotal                                                            0.042393
# num_distinct_items                                                  0.007291
# min_item_price                                                      0.052849
# max_item_price                                                      0.085878
# total_onshift_dashers                                              -0.178175
# total_busy_dashers                                                 -0.184425
# total_outstanding_orders                                           -0.166006
# estimated_order_place_duration                                      1.000000
# estimated_store_to_consumer_driving_duration                       -0.024425
# delivery_duration_secs                                              0.105681
# create_week                                                         0.015969
# create_hour                                                        -0.027398
# create_month                                                       -0.006675
#
#                                               estimated_store_to_consumer_driving_duration  \
# market_id                                                                         0.006854
# store_id                                                                          0.001913
# total_items                                                                       0.007910
# subtotal                                                                          0.034453
# num_distinct_items                                                                0.022860
# min_item_price                                                                    0.001838
# max_item_price                                                                    0.026043
# total_onshift_dashers                                                             0.041857
# total_busy_dashers                                                                0.040316
# total_outstanding_orders                                                          0.035992
# estimated_order_place_duration                                                   -0.024425
# estimated_store_to_consumer_driving_duration                                      1.000000
# delivery_duration_secs                                                            0.238904
# create_week                                                                       0.007817
# create_hour                                                                      -0.022821
# create_month                                                                      0.012161
#
#                                               delivery_duration_secs  \
# market_id                                                  -0.049624
# store_id                                                   -0.009647
# total_items                                                 0.129359
# subtotal                                                    0.215657
# num_distinct_items                                          0.154516
# min_item_price                                              0.014959
# max_item_price                                              0.139452
# total_onshift_dashers                                       0.077946
# total_busy_dashers                                          0.096235
# total_outstanding_orders                                    0.186469
# estimated_order_place_duration                              0.105681
# estimated_store_to_consumer_driving_duration                0.238904
# delivery_duration_secs                                      1.000000
# create_week                                                 0.001203
# create_hour                                                -0.172695
# create_month                                                0.065449
#
#                                               create_week  create_hour  \
# market_id                                       -0.002365    -0.014624
# store_id                                        -0.000465     0.010008
# total_items                                      0.028826    -0.080102
# subtotal                                         0.035009    -0.192589
# num_distinct_items                               0.032868    -0.119512
# min_item_price                                  -0.002013    -0.053613
# max_item_price                                   0.029479    -0.197267
# total_onshift_dashers                            0.086620    -0.382202
# total_busy_dashers                               0.069732    -0.358519
# total_outstanding_orders                         0.072138    -0.370555
# estimated_order_place_duration                   0.015969    -0.027398
# estimated_store_to_consumer_driving_duration     0.007817    -0.022821
# delivery_duration_secs                           0.001203    -0.172695
# create_week                                      1.000000     0.021369
# create_hour                                      0.021369     1.000000
# create_month                                    -0.102396    -0.032174
#
#                                               create_month
# market_id                                         0.042108
# store_id                                          0.003774
# total_items                                      -0.005475
# subtotal                                         -0.005756
# num_distinct_items                               -0.002032
# min_item_price                                    0.003308
# max_item_price                                    0.005389
# total_onshift_dashers                             0.023269
# total_busy_dashers                               -0.043374
# total_outstanding_orders                          0.042183
# estimated_order_place_duration                   -0.006675
# estimated_store_to_consumer_driving_duration      0.012161
# delivery_duration_secs                            0.065449
# create_week                                      -0.102396
# create_hour                                      -0.032174
# create_month                                      1.000000

# %%
#create Scatter Plot between Between total_busy_dashers & total_onshift_dashers
plt.scatter(updated_df.total_busy_dashers, updated_df.total_onshift_dashers)
plt.title('total_busy_dashers vs. total_onshift_dashers')
plt.xlabel('total_busy_dashers')
plt.ylabel('total_onshift_dashers')
# Out:
# Text(0, 0.5, 'total_onshift_dashers')

# %%
#create Scatter Plot between Between total_outstanding_orders & total_onshift_dashers
plt.scatter(updated_df.total_outstanding_orders, updated_df.total_onshift_dashers)
plt.title('total_outstanding_orders vs. total_onshift_dashers')
plt.xlabel('total_outstanding_orders')
plt.ylabel('total_onshift_dashers')
# Out:
# Text(0, 0.5, 'total_onshift_dashers')

# %%
#create Scatter Plot between Scatter Plot Between total_outstanding_orders & total_busy_dashers
plt.scatter(updated_df.total_outstanding_orders, updated_df.total_busy_dashers)
plt.title('total_outstanding_orders vs. total_busy_dashers')
plt.xlabel('total_outstanding_orders')
plt.ylabel('total_busy_dashers')
# Out:
# Text(0, 0.5, 'total_busy_dashers')

# %%
#create Scatter Plot Between total_busy_dashers & create_hour

plt.scatter(updated_df.total_busy_dashers, updated_df.create_hour)
plt.title('total_busy_dashers vs. create_hour')
plt.xlabel('total_busy_dashers')
plt.ylabel('create_hour')
# Out:
# Text(0, 0.5, 'create_hour')

# %%
#create Scatter Plot Between total_outstanding_orders & create_hour

plt.scatter(updated_df.total_outstanding_orders, updated_df.create_hour)
plt.title('total_outstanding_orders vs. create_hour')
plt.xlabel('total_outstanding_orders')
plt.ylabel('create_hour')
# Out:
# Text(0, 0.5, 'create_hour')

# %%
updated_df.corr()
# Out:
#                                               market_id  store_id  \
# market_id                                      1.000000  0.017393
# store_id                                       0.017393  1.000000
# total_items                                   -0.008050 -0.009569
# subtotal                                      -0.017392 -0.013073
# num_distinct_items                             0.000929 -0.013033
# min_item_price                                 0.001045 -0.008014
# max_item_price                                -0.002757 -0.019012
# total_onshift_dashers                          0.065754 -0.021962
# total_busy_dashers                             0.058037 -0.022198
# total_outstanding_orders                       0.064395 -0.019576
# estimated_order_place_duration                -0.053183  0.017037
# estimated_store_to_consumer_driving_duration   0.006854  0.001913
# delivery_duration_secs                        -0.049624 -0.009647
# create_week                                   -0.002365 -0.000465
# create_hour                                   -0.014624  0.010008
# create_month                                   0.042108  0.003774
#
#                                               total_items  subtotal  \
# market_id                                       -0.008050 -0.017392
# store_id                                        -0.009569 -0.013073
# total_items                                      1.000000  0.623052
# subtotal                                         0.623052  1.000000
# num_distinct_items                               0.842965  0.679730
# min_item_price                                  -0.452736  0.026496
# max_item_price                                  -0.056881  0.513033
# total_onshift_dashers                            0.039693  0.135509
# total_busy_dashers                               0.035413  0.129659
# total_outstanding_orders                         0.041831  0.134613
# estimated_order_place_duration                  -0.018311  0.042393
# estimated_store_to_consumer_driving_duration     0.007910  0.034453
# delivery_duration_secs                           0.129359  0.215657
# create_week                                      0.028826  0.035009
# create_hour                                     -0.080102 -0.192589
# create_month                                    -0.005475 -0.005756
#
#                                               num_distinct_items  \
# market_id                                               0.000929
# store_id                                               -0.013033
# total_items                                             0.842965
# subtotal                                                0.679730
# num_distinct_items                                      1.000000
# min_item_price                                         -0.466307
# max_item_price                                          0.050520
# total_onshift_dashers                                   0.067757
# total_busy_dashers                                      0.062071
# total_outstanding_orders                                0.069284
# estimated_order_place_duration                          0.007291
# estimated_store_to_consumer_driving_duration            0.022860
# delivery_duration_secs                                  0.154516
# create_week                                             0.032868
# create_hour                                            -0.119512
# create_month                                           -0.002032
#
#                                               min_item_price  max_item_price  \
# market_id                                           0.001045       -0.002757
# store_id                                           -0.008014       -0.019012
# total_items                                        -0.452736       -0.056881
# subtotal                                            0.026496        0.513033
# num_distinct_items                                 -0.466307        0.050520
# min_item_price                                      1.000000        0.528677
# max_item_price                                      0.528677        1.000000
# total_onshift_dashers                               0.045494        0.143101
# total_busy_dashers                                  0.046686        0.140248
# total_outstanding_orders                            0.044006        0.140401
# estimated_order_place_duration                      0.052849        0.085878
# estimated_store_to_consumer_driving_duration        0.001838        0.026043
# delivery_duration_secs                              0.014959        0.139452
# create_week                                        -0.002013        0.029479
# create_hour                                        -0.053613       -0.197267
# create_month                                        0.003308        0.005389
#
#                                               total_onshift_dashers  \
# market_id                                                  0.065754
# store_id                                                  -0.021962
# total_items                                                0.039693
# subtotal                                                   0.135509
# num_distinct_items                                         0.067757
# min_item_price                                             0.045494
# max_item_price                                             0.143101
# total_onshift_dashers                                      1.000000
# total_busy_dashers                                         0.945838
# total_outstanding_orders                                   0.938196
# estimated_order_place_duration                            -0.178175
# estimated_store_to_consumer_driving_duration               0.041857
# delivery_duration_secs                                     0.077946
# create_week                                                0.086620
# create_hour                                               -0.382202
# create_month                                               0.023269
#
#                                               total_busy_dashers  \
# market_id                                               0.058037
# store_id                                               -0.022198
# total_items                                             0.035413
# subtotal                                                0.129659
# num_distinct_items                                      0.062071
# min_item_price                                          0.046686
# max_item_price                                          0.140248
# total_onshift_dashers                                   0.945838
# total_busy_dashers                                      1.000000
# total_outstanding_orders                                0.935364
# estimated_order_place_duration                         -0.184425
# estimated_store_to_consumer_driving_duration            0.040316
# delivery_duration_secs                                  0.096235
# create_week                                             0.069732
# create_hour                                            -0.358519
# create_month                                           -0.043374
#
#                                               total_outstanding_orders  \
# market_id                                                     0.064395
# store_id                                                     -0.019576
# total_items                                                   0.041831
# subtotal                                                      0.134613
# num_distinct_items                                            0.069284
# min_item_price                                                0.044006
# max_item_price                                                0.140401
# total_onshift_dashers                                         0.938196
# total_busy_dashers                                            0.935364
# total_outstanding_orders                                      1.000000
# estimated_order_place_duration                               -0.166006
# estimated_store_to_consumer_driving_duration                  0.035992
# delivery_duration_secs                                        0.186469
# create_week                                                   0.072138
# create_hour                                                  -0.370555
# create_month                                                  0.042183
#
#                                               estimated_order_place_duration  \
# market_id                                                          -0.053183
# store_id                                                            0.017037
# total_items                                                        -0.018311
# subtotal                                                            0.042393
# num_distinct_items                                                  0.007291
# min_item_price                                                      0.052849
# max_item_price                                                      0.085878
# total_onshift_dashers                                              -0.178175
# total_busy_dashers                                                 -0.184425
# total_outstanding_orders                                           -0.166006
# estimated_order_place_duration                                      1.000000
# estimated_store_to_consumer_driving_duration                       -0.024425
# delivery_duration_secs                                              0.105681
# create_week                                                         0.015969
# create_hour                                                        -0.027398
# create_month                                                       -0.006675
#
#                                               estimated_store_to_consumer_driving_duration  \
# market_id                                                                         0.006854
# store_id                                                                          0.001913
# total_items                                                                       0.007910
# subtotal                                                                          0.034453
# num_distinct_items                                                                0.022860
# min_item_price                                                                    0.001838
# max_item_price                                                                    0.026043
# total_onshift_dashers                                                             0.041857
# total_busy_dashers                                                                0.040316
# total_outstanding_orders                                                          0.035992
# estimated_order_place_duration                                                   -0.024425
# estimated_store_to_consumer_driving_duration                                      1.000000
# delivery_duration_secs                                                            0.238904
# create_week                                                                       0.007817
# create_hour                                                                      -0.022821
# create_month                                                                      0.012161
#
#                                               delivery_duration_secs  \
# market_id                                                  -0.049624
# store_id                                                   -0.009647
# total_items                                                 0.129359
# subtotal                                                    0.215657
# num_distinct_items                                          0.154516
# min_item_price                                              0.014959
# max_item_price                                              0.139452
# total_onshift_dashers                                       0.077946
# total_busy_dashers                                          0.096235
# total_outstanding_orders                                    0.186469
# estimated_order_place_duration                              0.105681
# estimated_store_to_consumer_driving_duration                0.238904
# delivery_duration_secs                                      1.000000
# create_week                                                 0.001203
# create_hour                                                -0.172695
# create_month                                                0.065449
#
#                                               create_week  create_hour  \
# market_id                                       -0.002365    -0.014624
# store_id                                        -0.000465     0.010008
# total_items                                      0.028826    -0.080102
# subtotal                                         0.035009    -0.192589
# num_distinct_items                               0.032868    -0.119512
# min_item_price                                  -0.002013    -0.053613
# max_item_price                                   0.029479    -0.197267
# total_onshift_dashers                            0.086620    -0.382202
# total_busy_dashers                               0.069732    -0.358519
# total_outstanding_orders                         0.072138    -0.370555
# estimated_order_place_duration                   0.015969    -0.027398
# estimated_store_to_consumer_driving_duration     0.007817    -0.022821
# delivery_duration_secs                           0.001203    -0.172695
# create_week                                      1.000000     0.021369
# create_hour                                      0.021369     1.000000
# create_month                                    -0.102396    -0.032174
#
#                                               create_month
# market_id                                         0.042108
# store_id                                          0.003774
# total_items                                      -0.005475
# subtotal                                         -0.005756
# num_distinct_items                               -0.002032
# min_item_price                                    0.003308
# max_item_price                                    0.005389
# total_onshift_dashers                             0.023269
# total_busy_dashers                               -0.043374
# total_outstanding_orders                          0.042183
# estimated_order_place_duration                   -0.006675
# estimated_store_to_consumer_driving_duration      0.012161
# delivery_duration_secs                            0.065449
# create_week                                      -0.102396
# create_hour                                      -0.032174
# create_month                                      1.000000

# %%
#Basic Heatmap of all the columns:
sns.heatmap(updated_df.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(updated_df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
#Correlation of Independent Variables with the Dependent Variable (Delivery Duration):

plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(updated_df.corr()[['delivery_duration_secs']].sort_values(by='delivery_duration_secs', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with delivery_duration_secs', fontdict={'fontsize':18}, pad=16)
# Out:
# Text(0.5, 1.0, 'Features Correlating with delivery_duration_secs')

# %% [markdown]
# # Multivariate Analysis

# %%
#clustering
kmeans = KMeans(n_clusters=4)
features = ['delivery_duration_secs', 'total_onshift_dashers']
marketdata = updated_df[features]
kmeans.fit(marketdata)
labels = kmeans.labels_

# %%
plt.scatter(marketdata['delivery_duration_secs'], marketdata['total_onshift_dashers'], c=labels)
plt.show()

# %%
kmeans = KMeans(n_clusters=3)
features = ['total_busy_dashers', 'total_onshift_dashers']
marketdata = updated_df[features]
kmeans.fit(marketdata)
labels = kmeans.labels_

plt.scatter(marketdata['total_busy_dashers'], marketdata['total_onshift_dashers'], c=labels)
plt.show()

# %%
kmeans = KMeans(n_clusters=3)
features = ['total_outstanding_orders', 'total_onshift_dashers']
marketdata = updated_df[features]
kmeans.fit(marketdata)
labels = kmeans.labels_

plt.scatter(marketdata['total_outstanding_orders'], marketdata['total_onshift_dashers'], c=labels)
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
features = ['total_busy_dashers', 'total_outstanding_orders']
marketdata = updated_df[features]
kmeans.fit(marketdata)
labels = kmeans.labels_

plt.scatter(marketdata['total_busy_dashers'], marketdata['total_outstanding_orders'], c=labels)
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
features = ['delivery_duration_secs', 'total_outstanding_orders']
marketdata = updated_df[features]
kmeans.fit(marketdata)
labels = kmeans.labels_

plt.scatter(marketdata['delivery_duration_secs'], marketdata['total_outstanding_orders'], c=labels)
plt.show()

# %%
updated_df['total_items_cat'] = np.where(updated_df['total_items'] > 5 ,'>5','<=5')

# %%
updated_df['total_items_cat']=updated_df['total_items_cat'].astype('category')
updated_df['total_items_cat_c']=updated_df['total_items_cat'].cat.codes

# %%
updated_df
# Out:
#         market_id actual_delivery_time  store_id  total_items  subtotal  \
# 0             1.0  2015-02-06 23:27:16      1845            4  0.447317
# 1             2.0  2015-02-10 22:56:29      5477            1 -0.428871
# 2             3.0  2015-01-22 21:09:09      5477            1 -0.428871
# 3             3.0  2015-02-03 22:13:00      5477            6  2.414049
# 4             3.0  2015-02-15 03:20:26      5477            3  0.708297
# ...           ...                  ...       ...          ...       ...
# 194741        1.0  2015-02-17 01:24:48      2956            3 -0.719418
# 194742        1.0  2015-02-13 00:58:22      2956            6  0.202257
# 194743        1.0  2015-01-24 05:36:16      2956            5 -0.465260
# 194744        1.0  2015-02-01 19:23:22      3630            1 -0.841095
# 194745        1.0  2015-02-08 20:01:41      3630            4 -0.028019
#
#         num_distinct_items  min_item_price  max_item_price  \
# 0                 0.852293       -0.251422        0.168476
# 1                -1.045532        1.436044        0.476361
# 2                -1.045532        2.436913        1.432527
# 3                 1.484901       -0.165347        1.241294
# 4                 0.219685        0.835522        0.858828
# ...                    ...             ...             ...
# 194741            0.219685       -0.675790       -0.959799
# 194742            0.852293       -0.555686       -0.623229
# 194743            0.219685       -0.765868       -1.437882
# 194744           -1.045532       -0.295460       -1.177805
# 194745            0.852293       -0.515651       -0.766654
#
#         total_onshift_dashers  total_busy_dashers  total_outstanding_orders  \
# 0                   -0.343738           -0.885355                 -0.720733
# 1                   -1.303821           -1.272896                 -1.095052
# 2                   -1.303821           -1.337486                 -1.134454
# 3                   -1.303821           -1.305191                 -1.095052
# 4                   -1.153808           -1.143715                 -0.957145
# ...                       ...                 ...                       ...
# 194741              -0.823779           -0.788469                 -0.681331
# 194742              -0.973792           -0.982240                 -0.858640
# 194743              -0.163722           -0.013387                 -0.346414
# 194744              -1.123805           -1.111420                 -0.898042
# 194745              -0.733772           -0.691584                 -0.681331
#
#         estimated_order_place_duration  \
# 0                             1.523068
# 1                             1.523068
# 2                             1.523068
# 3                             1.523068
# 4                             1.523068
# ...                                ...
# 194741                       -0.639277
# 194742                       -0.639277
# 194743                       -0.639277
# 194744                        1.523068
# 194745                        1.523068
#
#         estimated_store_to_consumer_driving_duration  delivery_duration_secs  \
# 0                                           1.439918                0.870613
# 1                                           0.660403                1.098965
# 2                                           0.660403               -0.991619
# 3                                          -1.167581                0.214451
# 4                                           0.478061               -0.424002
# ...                                              ...                     ...
# 194741                                     -0.976121                0.989915
# 194742                                      1.686080                0.501522
# 194743                                      1.139053                0.152004
# 194744                                     -0.734517                0.989915
# 194745                                     -1.874158               -0.574994
#
#         create_week  create_hour  create_month total_items_cat  \
# 0          0.383764     1.559542      0.729018             <=5
# 1         -1.082953     1.444138      0.729018             <=5
# 2         -0.105141     1.328733     -1.371708             <=5
# 3         -1.082953     1.444138      0.729018              >5
# 4          1.361576    -0.748554      0.729018             <=5
# ...             ...          ...           ...             ...
# 194741    -1.082953    -0.979363      0.729018             <=5
# 194742     0.383764    -0.979363      0.729018              >5
# 194743     0.872670    -0.517744     -1.371708             <=5
# 194744     1.361576     1.097923      0.729018             <=5
# 194745     1.361576     1.213328      0.729018             <=5
#
#         total_items_cat_c
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
# ...                   ...
# 194741                  0
# 194742                  1
# 194743                  0
# 194744                  0
# 194745                  0
#
# [194223 rows x 19 columns]

# %% [markdown]
# # MACHINE LEARNING MODEL

# %% [markdown]
# # Random Forest

# %%
# features engineering
#find the feature with highest to least important features

y=updated_df['delivery_duration_secs'].astype('int64')
X=updated_df[['market_id','store_id','create_hour','total_onshift_dashers', 'total_busy_dashers','create_week',
            'total_outstanding_orders','total_items','num_distinct_items','min_item_price','max_item_price','subtotal']]
#Data partitioning into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=109)

# random forest fit
rf = RandomForestRegressor(n_estimators = 300,min_samples_split=8,max_features =4)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_features=4, min_samples_split=8, n_estimators=300)

# %%
features = X_train.columns
importances = rf.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(12,16))
plt.title('Feature Importances for Random Forest')
plt.barh(range(len(indices)), importances[indices], color='g', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
# Out:
# Text(0.5, 0, 'Relative Importance')

# %%
#error display function
def run_error_result(actual,forecast,name):
    def mae(actual,forecast):
        result = 0 
        for a,f in zip(actual,forecast):
            result += abs(a-f)
        return result/len(forecast)

    def r_two_score(actual, forecast):
        r2 = metrics.r2_score(actual, forecast)
        return r2

    def mse(actual, forecast): 
        mse = metrics.mean_squared_error(actual, forecast)
        
        return mse

    def rmse(actual, forecast): 
        rmse = np.sqrt(mean_squared_error(actual, forecast))
        return rmse    
    return pd.DataFrame({'MAE':[mae(actual, forecast)],'MSE': [mse(actual,forecast)],'RMSE': [rmse(actual,forecast)],'R2_SCORE': [r_two_score(actual,forecast)]},index=pd.Series([name]))

# %%
#prepare data for Tree model 
def delivery_time_rf(data, groupby, estimators):
    y=data['delivery_duration_secs'].astype('int64')
    X=data[groupby]
    #Data partitioning into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=109)  

    # random forest fit
    rf = RandomForestRegressor(n_estimators = estimators,min_samples_split=8,max_features =4)
    rf.fit(X_train, y_train)

    ## predict test set  (out-sample)
    out_forecast = rf.predict(X_test)
    ## predict train set  (in-sample)
    in_forecast = rf.predict(X_train)
    
    print(run_error_result(y_test, out_forecast,'Out-sample'))
    print(run_error_result(y_train, in_forecast,'In-sample'))

# %%
delivery_time_rf(updated_df, ['market_id','store_id','create_hour','total_onshift_dashers', 'total_busy_dashers','total_outstanding_orders','min_item_price','max_item_price','subtotal','create_week'],300)
# Out:
#                  MAE       MSE      RMSE  R2_SCORE
# Out-sample  0.404211  0.409281  0.639751  0.195608
#                MAE       MSE      RMSE  R2_SCORE
# In-sample  0.24006  0.149931  0.387209  0.703077

# %% [markdown]
# # Linear Regression

# %%
def delivery_time_reg(data, groupby):
    y=data['delivery_duration_secs'].astype('int64')
    X=data[groupby]
    #Data partitioning into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40,random_state=109)  

    #fit LR model
    model = LinearRegression().fit(X_train, y_train)    
    # get importance
    importance = model.coef_
    # plot feature importance
    plt.bar([x for x in range(len(importance))], importance)
    plt.show()
    
    # with statsmodels
    x_train = sm.add_constant(X_train) # adding a constant
    x_test = sm.add_constant(X_test) # adding a constant
    
    model = sm.OLS(y_train, X_train).fit()
    print(model.summary())
    ## predict test set  (out-sample)
    out_forecast = model.predict(X_test)
    ## predict train set  (in-sample)
    in_forecast = model.predict(X_train)
    
    print(run_error_result(y_test, out_forecast,'Out-sample'))
    print(run_error_result(y_train, in_forecast,'In-sample'))

# %%
delivery_time_reg(updated_df, ['market_id','store_id','create_hour','total_onshift_dashers', 'total_busy_dashers','total_outstanding_orders','min_item_price','max_item_price','subtotal','create_week'])
# Out:
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     delivery_duration_secs   R-squared (uncentered):                   0.115
# Model:                                OLS   Adj. R-squared (uncentered):              0.115
# Method:                     Least Squares   F-statistic:                              1510.
# Date:                    Sat, 13 May 2023   Prob (F-statistic):                        0.00
# Time:                            17:55:57   Log-Likelihood:                     -1.1878e+05
# No. Observations:                  116533   AIC:                                  2.376e+05
# Df Residuals:                      116523   BIC:                                  2.377e+05
# Df Model:                              10
# Covariance Type:                nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# market_id                    0.0018      0.001      1.951      0.051   -8.08e-06       0.004
# store_id                  1.437e-05    7.6e-07     18.897      0.000    1.29e-05    1.59e-05
# create_hour                 -0.0677      0.002    -31.231      0.000      -0.072      -0.063
# total_onshift_dashers       -0.4130      0.007    -59.779      0.000      -0.427      -0.399
# total_busy_dashers          -0.1511      0.007    -22.532      0.000      -0.164      -0.138
# total_outstanding_orders     0.5821      0.006     92.473      0.000       0.570       0.594
# min_item_price              -0.0056      0.002     -2.254      0.024      -0.010      -0.001
# max_item_price               0.0177      0.003      6.149      0.000       0.012       0.023
# subtotal                     0.0962      0.002     39.308      0.000       0.091       0.101
# create_week                 -0.0079      0.002     -4.019      0.000      -0.012      -0.004
# ==============================================================================
# Omnibus:                    56197.028   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           551432.748
# Skew:                           2.097   Prob(JB):                         0.00
# Kurtosis:                      12.797   Cond. No.                     1.77e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.77e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                  MAE       MSE      RMSE  R2_SCORE
# Out-sample  0.408805  0.458094  0.676826  0.105837
#                MAE       MSE      RMSE  R2_SCORE
# In-sample  0.40737  0.449648  0.670558  0.104222

# %% [markdown]
# # KNN

# %%
#prepare data for knn model 
def delivery_time_knn(data, groupby, k):
    y=data['delivery_duration_secs'].astype('int64')
    X=data[groupby]
    #Data partitioning into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=109)  

    scaler = StandardScaler()  
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test) 
    
    #KNN fit
    classifier = KNeighborsClassifier(n_neighbors=k)  
    knn = classifier.fit(X_train, y_train)

    ## predict test set  (out-sample)
    out_forecast = knn.predict(X_test)
    ## predict train set  (in-sample)
    in_forecast = knn.predict(X_train)
    print(run_error_result(y_test, out_forecast,'Out-sample'))
    print(run_error_result(y_train, in_forecast,'In-sample'))

# %%
delivery_time_knn(updated_df, ['market_id','create_hour','total_onshift_dashers','total_busy_dashers','total_outstanding_orders'],2)
# Out:
#                  MAE       MSE      RMSE  R2_SCORE
# Out-sample  0.456794  0.660305  0.812592 -0.297748
#                 MAE       MSE      RMSE  R2_SCORE
# In-sample  0.327621  0.497911  0.705628  0.013939
